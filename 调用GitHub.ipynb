# %%
# !git clone https://github.com/liuhuan1111/RainDrop.git
# Out:
# Cloning into 'RainDrop'...

# %%
cd RainDrop
# Out:
# [WinError 2] 系统找不到指定的文件。: 'RainDrop'
# C:\Users\76416\RainDrop

# %%
ls
# Out:
#  驱动器 C 中的卷没有标签。
#  卷的序列号是 B0EE-A3C0
#
#  C:\Users\76416\RainDrop 的目录
#
# 2022/04/08  14:50    <DIR>          .
# 2022/04/08  14:50    <DIR>          ..
# 2022/04/08  14:07    <DIR>          .idea
# 2022/04/08  14:07    <DIR>          __pycache__
# 2022/04/08  14:36           127,689 altair演示.ipynb
# 2022/04/08  15:36               454 altair演示.py
# 2022/04/08  14:07               808 DataTest.py
# 2022/04/08  14:07             1,625 DataTrain.py
# 2022/04/08  14:35               478 demo.py
# 2022/04/08  14:07               182 Desktop.ini
# 2022/04/08  14:07            58,500 HuberLoss_list.txt
# 2022/04/08  15:36           574,156 loss.jpg
# 2022/04/08  14:07            58,500 MAELoss_list.txt
# 2022/04/08  14:07         1,580,949 model.pth
# 2022/04/08  14:07            58,500 MSELoss_list.txt
# 2022/04/08  14:07             2,711 sp.py
# 2022/04/08  14:07               731 Test.py
# 2022/04/08  14:07             2,412 Train.py
# 2022/04/08  14:07             2,519 unet.py
# ...

# %%
# !python demo.py
# Out:
# Figure(3200x2400)

# %%
# %run altair演示.py
# Out:
# Displaying chart at http://localhost:16292/

# %%
# %run demo.py
